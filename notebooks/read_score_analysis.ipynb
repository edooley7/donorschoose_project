# %%
from __future__ import division
import pandas as pd
import pickle
import numpy as np
pd.options.mode.chained_assignment = None

# %%
df = pd.DataFrame(pickle.load(open('../data_files/read_score.pkl', 'rb')))

# %%
df
# Out:
#                               _projectid  RESP  \
# 0       02c7bc35161ba1b988e1c04c115c0a6f     1
# 1       0899b88e9c28d26793af47e3c06cf26e     1
# 2       038fbbffb42416d0ca8ff46dff7ce743     0
# 3       0c317340d757b09c7a56390cb1b5602e     1
# 4       0a89a92fadb414ac19172e889d78fe21     0
# 5       10a706016480821e13ee4673f642da3f     0
# 6       0b3cb9e29158ca9c6f4302ae643f80ed     0
# 7       1200b446a6ccc476247fce13a64dec96     1
# 8       0e70042b002fcd2b31a64b314b633335     1
# 9       139bfccb0b2544e763eeef343d0f21e5     1
# 10      130dc4e7a295e3b4bdd489cdf9c0ea23     1
# 11      13d5003132fce51c9060568338e4eb92     1
# 12      139b4c7eab05f1afa5468359679328b5     1
# 13      18390d3bb7c236accc8230f6dac831d0     0
# 14      1ab572297b7d093431d7e0bba1ea9f27     1
# 15      1b7d2788f6d3fc85e08e9e47d78bb428     1
# 16      1d6e089e131e8ad5b98387fe69e34faa     1
# 17      24a66b889f42f19da19093af7097cdbc     1
# 18      27b2c26285891b8f83641d7d46b840c4     1
# ...

# %%
df.groupby("RESP").mean()
# Out:
#            ari    coleman  flesch_grade  flesch_ease      dale    gunning  \
# RESP
# 0     9.612740  10.281109      8.523451    63.749708  5.506086  11.171627
# 1     9.657219  10.292788      8.519271    63.931551  5.487591  11.179688
#
#             lix       smog
# RESP
# 0     42.307017  10.736479
# 1     42.361101  10.729942

# %%
(9.657219-9.612740)/9.612740
# Out:
# 0.004627088634457922

# %%
(10.292788-10.281109)/10.281109
# Out:
# 0.0011359669467563378

# %%
(8.519271-8.523451)/8.523451
# Out:
# -0.0004904116888804605

# %%
(63.931551-63.749708)/63.749708
# Out:
# 0.0028524522810363406

# %%
(5.487591-5.506086)/5.506086
# Out:
# -0.0033590103750649205

# %%
(11.179688-11.171627)/11.171627
# Out:
# 0.000721560073568483

# %%
(42.361101-42.307017)/42.307017
# Out:
# 0.0012783694960104613

# %%
(10.729942-10.736479)/10.736479
# Out:
# -0.0006088588260639073
